# %% [markdown]
# # Databricks Notebook
# - %md makes it a markdown cell in databricks

# %%
print("Hello from home lecture 02")
# Out:
# Hello from home lecture 02

# %%
print("yo, VsCode")
# Out:
# yo, VsCode
