-- %%
SHOW CATALOGS;

-- %%
SHOW SCHEMAS IN data;

-- %%
SHOW VOLUMES IN data.olympic_games;

LIST '/Volumes/data/olympic_games/raw_data';

-- %%
%python
_sqldf.display() # display the files in the session

-- %%
%python
volume_path = '/Volumes/data/olympic_games/raw_data' # the path to the volume

files_in_volume = spark.sql(f"LIST '{volume_path}';") # create a Spark DataFrame - Lazy Eval
files_in_volume.display() # display the files in the volume

-- %%
%python
display(files_in_volume) # display the files in the volume
